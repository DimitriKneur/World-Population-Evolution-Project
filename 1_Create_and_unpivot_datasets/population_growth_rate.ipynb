columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   economy  266 non-null    object
#  1   YR2000   266 non-null    float64
#  2   YR2001   266 non-null    float64
#  3   YR2002   266 non-null    float64
#  4   YR2003   266 non-null    float64
#  5   YR2004   266 non-null    float64
#  6   YR2005   266 non-null    float64
#  7   YR2006   266 non-null    float64
#  8   YR2007   266 non-null    float64
#  9   YR2008   266 non-null    float64
#  10  YR2009   266 non-null    float64
#  11  YR2010   266 non-null    float64
#  12  YR2011   266 non-null    float64
#  13  YR2012   266 non-null    float64
#  14  YR2013   266 non-null    float64
#  15  YR2014   266 non-null    float64
#  16  YR2015   266 non-null    float64
#  17  YR2016   266 non-null    float64
#  18  YR2017   266 non-null    float64
#  19  YR2018   266 non-null    float64
# ...

# %%
df_unpivot= df.melt(id_vars=['economy'], var_name = 'Year', value_name= 'population_growth_rate')

# %%
df_unpivot
# Out:
#      economy    Year  population_growth_rate
# 0        ABW  YR2000                2.539234
# 1        AFE  YR2000                2.583579
# 2        AFG  YR2000                1.443803
# 3        AFW  YR2000                2.749600
# 4        AGO  YR2000                3.244121
# ...      ...     ...                     ...
# 5847     XKX  YR2021               -0.229016
# 5848     YEM  YR2021                2.137790
# 5849     ZAF  YR2021                0.998920
# 5850     ZMB  YR2021                2.840806
# 5851     ZWE  YR2021                2.045715
#
# [5852 rows x 3 columns]

# %%
df_unpivot['Year']= df_unpivot['Year'].str[2:]

# %%
df_unpivot.describe(include='all')
# Out:
#        economy  Year  population_growth_rate
# count     5852  5852             5852.000000
# unique     266    22                     NaN
# top        ABW  2000                     NaN
# freq        22   266                     NaN
# mean       NaN   NaN                1.338834
# std        NaN   NaN                1.467991
# min        NaN   NaN               -6.852118
# 25%        NaN   NaN                0.456875
# 50%        NaN   NaN                1.226128
# 75%        NaN   NaN                2.238607
# max        NaN   NaN               19.360429

# %%
df_growth_rate = df_unpivot.sort_values(by=['economy','Year'])

# %%
df_growth_rate
# Out:
#      economy  Year  population_growth_rate
# 0        ABW  2000                2.539234
# 266      ABW  2001                1.768757
# 532      ABW  2002                1.194718
# 798      ABW  2003                0.997396
# 1064     ABW  2004                0.900989
# ...      ...   ...                     ...
# 4787     ZWE  2017                2.043620
# 5053     ZWE  2018                2.020537
# 5319     ZWE  2019                1.989253
# 5585     ZWE  2020                2.031112
# 5851     ZWE  2021                2.045715
#
# [5852 rows x 3 columns]

# %%
df_growth_rate.to_csv("population_growth_rate.csv")
